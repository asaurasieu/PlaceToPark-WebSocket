# %%
from ultralytics import YOLO
import os
import yaml
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import glob

# %%
print("Loading dataset configuration...")
with open("Car-Model-v4.yolov8/data.yaml", "r") as f:
    data_config = yaml.safe_load(f)
    print(f"Dataset classes: {data_config['names']}")
    print(f"Number of classes: {len(data_config['names'])}")
    class_names = data_config['names']
# Out:
# Loading dataset configuration...
# Dataset classes: ['available', 'occupied']
# Number of classes: 2

# %%
print("\nStarting model training...")
model = YOLO("yolov8m.pt") 
dataset = "Car-Model-v4.yolov8/data.yaml"
results = model.train(
    data=dataset,
    epochs=50,
    imgsz=640,
    batch=16,
    name="parking_detection_model"
)
# Out:
# ...
# Starting model training...
# 100%|██████████| 49.7M/49.7M [00:01<00:00, 30.6MB/s]
# New https://pypi.org/project/ultralytics/8.3.91 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.9.7 torch-2.2.1 CPU (Apple M4 Pro)
# ...
